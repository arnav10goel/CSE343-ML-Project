# %% [markdown]
# ### Decision Tree

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Open the .csv files
X_train = pd.read_csv('/Users/arnav/Desktop/MachineLearning/ML_CSE343 Project/train_tfidf.csv')
X_test = pd.read_csv('/Users/arnav/Desktop/MachineLearning/ML_CSE343 Project/test_tfidf.csv')

X_train = X_train.drop(['Unnamed: 0'], axis=1)
X_test = X_test.drop(['Unnamed: 0'], axis=1)

# Check the shape of the data
print(X_train.shape)
print(X_test.shape)
# Out:
# (22500, 1000)
# (7500, 1000)

# %%
# Extract the features into a numpy array
X_train = X_train.values
X_test = X_test.values

# Open the labels
y_train_df = pd.read_csv('/Users/arnav/Desktop/MachineLearning/ML_CSE343 Project/CSE343-ML-Project/Data/Preprocessed-Data/train_labels.csv')
y_test_df = pd.read_csv('/Users/arnav/Desktop/MachineLearning/ML_CSE343 Project/CSE343-ML-Project/Data/Preprocessed-Data/test_labels.csv')

# Check the shape of the labels
print(y_train_df.shape)
print(y_test_df.shape)
# Out:
# (22500, 1)
# (7500, 1)

# %%
# Convert class to non_suicide = 0 and suicide = 1
y_train_temp = y_train_df['class'].values
y_test_temp = y_test_df['class'].values

# Check the shape of the labels
print(y_train_temp.shape)
print(y_test_temp.shape)

y_train = np.array([0 if label == "non-suicide" else 1 for label in y_train_temp])
y_test = np.array([0 if label == "non-suicide" else 1 for label in y_test_temp])

# Check the shape of the labels
print(y_train.shape)
print(y_test.shape)
# Out:
# (22500,)
# (7500,)
# (22500,)
# (7500,)

# %%
# Standard Preprocessing
# Check the mean and standard deviation of the data
print(np.mean(X_train), np.std(X_train))
# Out:
# 0.004686103127390068 0.0312074847455884

# %% [markdown]
# ### Running without Hyperparameter Tuning

# %%
# Decision Tree Classifier
dtclf = DecisionTreeClassifier()

# Fit the model
dtclf.fit(X_train, y_train)

# Predict on the test data
y_pred = dtclf.predict(X_test)

# %%
# Print the accuracy score
print("Accuracy Score:", accuracy_score(y_test, y_pred))

# Print the confusion matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Print AUC score
print("AUC Score:", roc_auc_score(y_test, y_pred))

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))

# Print weighted F1-score
print("Weighted F1-score:", f1_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy Score: 0.8536
# Confusion Matrix:
#  [[3362  346]
#  [ 752 3040]]
# AUC Score: 0.8541880026763891
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86      3708
#            1       0.90      0.80      0.85      3792
#
#     accuracy                           0.85      7500
#    macro avg       0.86      0.85      0.85      7500
# weighted avg       0.86      0.85      0.85      7500
#
# Weighted F1-score: 0.8532591198467946

# %%
# Print the precision and recall, among other metrics
print("Precision-Recall Metrics:\n", classification_report(y_test, y_pred, digits=3))

# # Plot the ROC curve
# fpr, tpr, thresholds = roc_curve(y_test, y_pred)
# roc_auc = auc(fpr, tpr)

# plt.figure(figsize=(10, 10))
# plt.title('ROC Curve')
# plt.plot(fpr, tpr, 'b', label='AUC = %0.2f' % roc_auc)
# plt.legend(loc='lower right')

# Plot the precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, y_pred)

plt.figure(figsize=(10, 10))
plt.title('Precision-Recall Curve')
plt.plot(recall, precision, 'b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# Precision-Recall Metrics:
#                precision    recall  f1-score   support
#
#            0      0.823     0.838     0.831      3708
#            1      0.839     0.824     0.832      3792
#
#     accuracy                          0.831      7500
#    macro avg      0.831     0.831     0.831      7500
# weighted avg      0.831     0.831     0.831      7500

# %% [markdown]
# ### Grid Search

# %%
# define hyperparameters grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
# Initialize Decision Tree Classifier
clf = DecisionTreeClassifier()

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(clf, param_grid, cv=5, verbose=2, n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  36.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  37.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  38.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  41.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  42.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  42.4s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  43.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  46.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  38.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  42.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  44.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  39.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  42.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  48.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  44.9s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  49.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  30.9s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  40.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  40.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  42.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  46.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  46.4s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  51.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  47.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  43.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  32.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  34.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  33.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  33.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  43.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  38.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  41.4s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  35.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  35.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  29.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  36.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  32.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  27.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  26.0s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  28.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  39.9s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  43.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  41.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  29.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  28.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  37.4s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  38.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  41.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  28.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  32.9s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  39.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  39.4s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  37.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  42.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  29.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  42.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  26.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  25.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  29.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  33.4s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  31.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  30.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  33.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  21.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  31.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  29.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  24.9s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  24.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  26.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  27.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  34.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  36.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  38.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  36.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  23.2s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  32.4s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  27.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  30.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  22.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  28.7s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  38.1s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  34.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  34.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=  31.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=  30.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   9.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  36.8s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  41.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   8.3s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=  31.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   8.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   7.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   5.4s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=   7.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   5.5s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=  26.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   5.6s
# [CV] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=  26.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   5.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   5.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   9.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=   9.4s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   7.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   7.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   6.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  10.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  10.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  10.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   6.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   7.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   5.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=   9.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=   9.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=   9.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=   8.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=   8.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   5.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   5.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   6.5s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   6.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   7.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=   9.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=   9.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=   9.5s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=   9.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=   9.4s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   6.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   5.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   6.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   6.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   5.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   8.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   8.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   8.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   8.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=   7.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   5.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   5.4s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   5.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   6.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   5.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   8.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   8.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   7.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   7.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=   8.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   5.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   5.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   5.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   6.5s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=   8.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   5.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=   8.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=   7.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=   7.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=   7.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   5.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   5.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   5.8s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   6.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=   8.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=   8.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=   7.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   5.4s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=   7.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=   7.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   5.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   5.0s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   6.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   7.2s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  10.4s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   7.9s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  10.5s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  10.4s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  10.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  10.6s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   7.1s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   6.7s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   6.3s
# [CV] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   6.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   9.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  13.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  12.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   8.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  13.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   8.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  13.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  12.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  12.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  12.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  12.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  15.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  16.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  16.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  16.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  17.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   8.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   9.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   8.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   8.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  11.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  10.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  11.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   8.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  11.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   7.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  10.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   7.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   8.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   9.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   7.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  11.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  11.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  10.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  10.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  11.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   7.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   7.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   7.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   8.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  11.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  11.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  10.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   7.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  10.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  10.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   7.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   7.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   7.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   7.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  10.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  10.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  10.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   7.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  10.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  10.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   7.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   7.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   7.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  10.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   8.8s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   8.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  11.7s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  12.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  15.3s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  15.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  14.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  14.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  11.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   8.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  14.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   8.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   9.6s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  10.0s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  14.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  13.4s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  14.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  13.9s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  14.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.5s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.2s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=  13.1s
# [CV] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=  13.3s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  15.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  21.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  21.6s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  20.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  20.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  11.6s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  20.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  11.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  17.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  18.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  18.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  22.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  23.3s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  23.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  23.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  25.6s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  13.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  12.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  16.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  16.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  13.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  20.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  18.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  20.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  18.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  17.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  11.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  10.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  12.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  11.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  16.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  16.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  15.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  11.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  16.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  15.3s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  10.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  11.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  12.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  13.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  18.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  18.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  16.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  12.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  18.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  17.6s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  12.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  12.3s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  14.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  15.2s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  21.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  14.2s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  22.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  21.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  21.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  20.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  14.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  15.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  16.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  16.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  15.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  22.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  23.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  21.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  22.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  21.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  14.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  14.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  14.3s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  14.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  19.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  13.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  17.8s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  19.4s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  19.1s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  17.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  11.3s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  11.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  11.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=  10.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.5s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  14.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  13.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  14.7s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  13.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  13.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   8.0s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   8.9s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.6s
# [CV] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.0s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  10.0s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  15.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  15.9s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  15.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  15.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  16.9s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  11.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  11.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  11.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  14.0s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  14.9s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  20.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  19.0s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  20.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  18.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  20.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  15.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  17.0s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  15.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  17.1s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  19.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  21.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  21.1s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  18.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  19.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  12.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  11.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  12.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  13.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  14.3s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  18.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  18.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  14.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  19.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  20.6s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  18.3s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  14.0s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  13.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  13.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  13.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  17.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  18.7s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  19.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  12.9s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  18.9s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  17.9s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  15.4s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  14.8s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  15.3s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  16.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  21.2s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  14.0s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  21.5s
# [CV] END criterion=gini, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  20.2s
# ...
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   9.0s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  11.6s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  11.2s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  11.5s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   8.4s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  11.6s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  11.9s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   8.1s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   8.4s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.5s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.3s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.3s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.8s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   8.1s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.2s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.3s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.7s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   7.9s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   8.4s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   8.7s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   9.1s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  11.3s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  11.7s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   8.1s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  11.2s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  11.4s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  10.5s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   7.7s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   8.2s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   8.8s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   8.3s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  11.2s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   8.7s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  11.4s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  11.0s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  10.8s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  10.6s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   7.7s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   7.7s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.3s
# [CV] END criterion=entropy, max_depth=40, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   9.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  12.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   8.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  12.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  12.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  12.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=best; total time=  12.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   9.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=   9.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  10.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=2, splitter=random; total time=  10.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  12.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  12.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  12.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  12.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   8.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=best; total time=  12.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   8.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   8.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=   9.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=5, splitter=random; total time=  10.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  12.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  12.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   8.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  13.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  12.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=best; total time=  12.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=   9.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  10.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  11.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=1, min_samples_split=10, splitter=random; total time=  12.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  14.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  14.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  13.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  13.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   9.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=best; total time=  14.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   9.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=  10.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   9.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=2, splitter=random; total time=   9.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  12.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  12.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  12.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  12.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   8.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=best; total time=  12.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   8.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=   8.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  10.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=5, splitter=random; total time=  11.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  14.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=  11.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  14.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  14.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  13.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=best; total time=  14.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=2, min_samples_split=10, splitter=random; total time=   9.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  12.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  12.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  11.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   8.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=best; total time=  12.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   7.7s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   9.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=   9.5s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=2, splitter=random; total time=  10.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  12.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  12.4s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  12.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   9.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  11.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=best; total time=  12.1s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   8.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   9.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   9.8s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=5, splitter=random; total time=   9.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  12.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  12.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  12.6s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  11.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   8.2s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=best; total time=  11.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   7.9s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   8.0s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   5.3s
# [CV] END criterion=entropy, max_depth=50, min_samples_leaf=4, min_samples_split=10, splitter=random; total time=   4.8s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              verbose=2)

# %%
# Print the best parameters
print(grid_search.best_params_)

# Retrieve the best estimator
best_clf = grid_search.best_estimator_
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}

# %%
# Predict on the test data
y_pred = best_clf.predict(X_test)

# Print the accuracy score
print("Accuracy Score:", accuracy_score(y_test, y_pred))

# Print the confusion matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Print AUC score
print("AUC Score:", roc_auc_score(y_test, y_pred))

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))

# Print weighted F1-score
print("Weighted F1-score:", f1_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy Score: 0.8536
# Confusion Matrix:
#  [[3362  346]
#  [ 752 3040]]
# AUC Score: 0.8541880026763891
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86      3708
#            1       0.90      0.80      0.85      3792
#
#     accuracy                           0.85      7500
#    macro avg       0.86      0.85      0.85      7500
# weighted avg       0.86      0.85      0.85      7500
#
# Weighted F1-score: 0.8532591198467946
